# %% [markdown]
# # **Imports**

# %%
import os
os.chdir("../..")
os.chdir(r"src")

from Polarization.polarization_plots import *
from Polarization.cos_pol import *

os.chdir("../")
# Out:
# /Users/alexandrequeant/Desktop/Travail-TSE/src
# /Users/alexandrequeant/Desktop/Travail-TSE

# %% [markdown]
# # **Polarization alone**

# %%
left = ['GUA']
right = ['TE']

# %%
choose_pol(left_side=left, right_side=right, axis=1, percentiles=[10, 90], with_parliament=False)
# Out:
# graph aldready exists

# %% [markdown]
# # **Polarization with cosinus on an axis**

# %%
draw_cos_pol(left_side=left, right_side=right, axis=1, percentiles=[10, 90], with_parliament=False)
# Out:
# computin polarization
# /Users/alexandrequeant/Desktop/Travail-TSE
#   7%|▋         | 1/14 [00:01<00:14,  1.13s/it]
# 0.5
# Year 2010 computed
#  14%|█▍        | 2/14 [00:02<00:14,  1.22s/it]
# 0.5
# Year 2011 computed
#  21%|██▏       | 3/14 [00:03<00:14,  1.34s/it]
# 0.5
# Year 2012 computed
#  29%|██▊       | 4/14 [00:05<00:15,  1.53s/it]
# 0.5
# Year 2013 computed
#  36%|███▌      | 5/14 [00:07<00:15,  1.71s/it]
# 0.5
# Year 2014 computed
#  43%|████▎     | 6/14 [00:09<00:15,  1.88s/it]
# 0.5
# Year 2015 computed
#  50%|█████     | 7/14 [00:44<01:28, 12.70s/it]
# 0.5377774234692009
# Year 2016 computed
#  57%|█████▋    | 8/14 [01:20<01:59, 19.85s/it]
# 0.535628323537392
# Year 2017 computed
#  64%|██████▍   | 9/14 [01:55<02:02, 24.58s/it]
# 0.5392390724761131
# Year 2018 computed
#  71%|███████▏  | 10/14 [02:30<01:51, 27.97s/it]
# 0.5248911719506675
# Year 2019 computed
#  79%|███████▊  | 11/14 [03:04<01:29, 29.88s/it]
# 0.5365199587517884
# Year 20110 computed
# ...

# %% [markdown]
# # **Loops to make graphs**

# %%
pairs_of_sources = [[['Lab'], ['Con']],
[['par'], ['GUA', 'TE', 'MET', 'DM', 'DE']],
[['GUA'], ['TE']],
[['GUA', 'MET'], ['TE', 'DM', 'DE']],
[['Lab', 'GUA', 'MET'], ['Con', 'TE', 'DM', 'DE']],
[['GUA', 'TE'], ['MET', 'DE', 'DM']],
[['par'], ['GUA', 'TE']]]

axes = [1, 2]

parliaments = [True, False]

# %%
for pair in pairs_of_sources:
    for axis in axes:
        for parliament in parliament:
            print(pair)
            draw_cos_pol(pair[0], pair[1], axis=axis, percentiles=[10, 90], with_parliament=parliament)
